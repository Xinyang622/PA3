# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomCrop(22),
     transforms.Scale(32),
     transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])

trainset = torchvision.datasets.CIFAR10(root='./datasets/CIFAR-10', train=True,
                                        download=True, transform=transform)

# testset = torchvision.datasets.CIFAR10(root='./datasets/CIFAR-10', train=False,
#                                        download=True, transform=transform)
# testloader = torch.utils.data.DataLoader(testset, batch_size=len(testset) / 100,
#                                          shuffle=False, num_workers=1)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %%
# get idea from Pytorch tutrial: http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
transform = transforms.Compose(
    [
     transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])

testset = torchvision.datasets.CIFAR10(root='./datasets/CIFAR-10', train=False,
                                        download=True, transform=transform)
testloader1 = torch.utils.data.DataLoader(testset, batch_size=len(testset),
                                          shuffle=False, num_workers=1)
testloader2 = torch.utils.data.DataLoader(testset, batch_size=len(testset)/100,
                                          shuffle=False, num_workers=1)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %%
#get idea from: https://gist.github.com/kevinzakka/d33bf8d6c7f06a9d8c76d97a7879f5cb
def train_valid_loader(data, batchSize, nWorker, validSize=0.1, shuffle=True, pin_memory=True):
    nTrain = len(data)
    indices = list(range(nTrain))
    split = int(np.floor(validSize * nTrain))
    if shuffle == True:
        #np.random.seed(randSeed)
        np.random.shuffle(indices)
        
    train_i, valid_i = indices[split:], indices[:split]
    
    train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_i)
    valid_sampler = torch.utils.data.sampler.SubsetRandomSampler(valid_i)
    
    trainLoader = torch.utils.data.DataLoader(data, 
                    batch_size=batchSize, sampler=train_sampler, 
                    num_workers=nWorker, pin_memory=pin_memory)
    
    validLoader = torch.utils.data.DataLoader(data, 
                    batch_size=batchSize, sampler=valid_sampler, 
                    num_workers=nWorker, pin_memory=pin_memory)
    return  trainLoader, validLoader, train_sampler

# %%
trainloader, validloader, nSample = train_valid_loader(trainset, 128, 1, 
                                           validSize=0.1, shuffle=True, pin_memory=True)
print (len(trainloader), len(validloader))
# Out:
# (352, 40)

# %%
class Net3(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(3, 46, 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv1.weight)
        self.conv1_bn = nn.BatchNorm2d(46)
        
        self.conv2 = nn.Conv2d(46, 92, 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv2.weight)
        # an affine operation: y = Wx + b
        self.conv2_bn = nn.BatchNorm2d(92)
        
        self.conv3  = nn.Conv2d(92, 184, 3, padding = 1, stride = 2)
        #torch.nn.init.xavier_normal(self.conv3.weight)
        self.conv3_bn = nn.BatchNorm2d(184)
        
        self.conv4  = nn.Conv2d(184, 368 , 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv4.weight)
        self.conv4_bn = nn.BatchNorm2d(368)
        
        self.conv5 = nn.Conv2d(368, 736, 3, padding = 1)
        self.conv5_bn = nn.BatchNorm2d(736)
        
        self.conv6 = nn.Conv2d(736, 1472, 3, padding = 1)
        self.conv6_bn = nn.BatchNorm2d(1472)
        
        self.fc1 = nn.Linear(1472 * 8 * 8, 736)
        #torch.nn.init.xavier_normal(self.fc1.weight)
        #self.fc1_bn = nn.BatchNorm1d(1472)
        
        self.fc2 = nn.Linear(736, 120)
        #torch.nn.init.xavier_normal(self.fc2.weight)
        #self.fc2_bn = nn.BatchNorm1d(120)
        
        self.fc3 = nn.Linear(120, 10)
        #torch.nn.init.xavier_normal(self.fc3.weight)
        #self.fc3_bn = nn.BatchNorm1d(84)
        
#         self.fc4 = nn.Linear(84, 10)
#         torch.nn.init.xavier_normal(self.fc4.weight)

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.relu(self.conv1_bn(self.conv1(x)))   
        x = F.relu(self.conv2_bn(self.conv2(x))) 
        x = F.relu(self.conv3_bn(self.conv3(x)))
        # If the size is a square you can only specify a single number
        x = F.relu(self.conv4_bn(self.conv4(x)))
        x = F.relu(self.conv5_bn(self.conv5(x)))
        x = F.max_pool2d(F.relu(self.conv6_bn(self.conv6(x))), 2)
        
        #x = F.max_pool2d(F.relu(self.conv4_bn(self.conv4(x))), 2)
        
        x = x.view(-1, self.num_flat_features(x))
        
#         x = F.relu(self.fc1_bn(self.fc1(x)))
#         x = F.relu(self.fc2_bn(self.fc2(x)))
#         x = F.relu(self.fc3_bn(self.fc3(x)))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc3(x))
        
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features


net = Net3()
net = net.cuda()
print(net)
# Out:
# Net (
#   (conv1): Conv2d(3, 46, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1_bn): BatchNorm2d(46, eps=1e-05, momentum=0.1, affine=True)
#   (conv2): Conv2d(46, 92, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_bn): BatchNorm2d(92, eps=1e-05, momentum=0.1, affine=True)
#   (conv3): Conv2d(92, 184, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3_bn): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True)
#   (conv4): Conv2d(184, 368, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4_bn): BatchNorm2d(368, eps=1e-05, momentum=0.1, affine=True)
#   (conv5): Conv2d(368, 736, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5_bn): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True)
#   (conv6): Conv2d(736, 1472, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv6_bn): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True)
#   (fc1): Linear (94208 -> 736)
#   (fc2): Linear (736 -> 120)
#   (fc3): Linear (120 -> 10)
# )

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
#optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr=0.001)#, weight_decay = 0.001)

# %%
def acc(dataloader):
    correct = 0
    total = 0
    for data in dataloader:
        images, labels = data
        outputs = net(Variable(images.cuda()))
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum()
    return 1.0 * correct / total

# %%
train = torch.zeros(100)
valid = torch.zeros(100)
test = torch.zeros(100)

for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.data[0]
        #if i % 300 == 299:    # print every 2000 mini-batches
    print('[%d, %5d] loss: %.3f' %
            (epoch + 1, i + 1, running_loss / 300))
    running_loss = 0.0
    train[epoch] = acc(trainloader)
    print('Accuracy of the network on the 45000 train images: %5.2f %%' % (
        train[epoch] * 100))
    
    valid[epoch] = acc(validloader)
    print('Accuracy of the network on the 5000 valid images: %5.2f %%' % (
        valid[epoch] * 100))
    
    test[epoch] = acc(testloader2)
    print('Accuracy of the network on the 10000 test images: %5.2f %%' % (
        test[epoch] * 100))
#print的时候 上面的valid和test没有标注清楚！！
print('Finished Training')
# Out:
# [1,   352] loss: 2.424
# Accuracy of the network on the 45000 train images: 35.63 %
# Accuracy of the network on the 5000 valid images: 34.70 %
# Accuracy of the network on the 10000 test images: 38.70 %
# [2,   352] loss: 1.828
# Accuracy of the network on the 45000 train images: 47.17 %
# Accuracy of the network on the 5000 valid images: 45.74 %
# Accuracy of the network on the 10000 test images: 49.92 %
# [3,   352] loss: 1.562
# Accuracy of the network on the 45000 train images: 56.53 %
# Accuracy of the network on the 5000 valid images: 56.12 %
# Accuracy of the network on the 10000 test images: 57.16 %
# [4,   352] loss: 1.368
# Accuracy of the network on the 45000 train images: 60.37 %
# Accuracy of the network on the 5000 valid images: 58.58 %
# Accuracy of the network on the 10000 test images: 59.19 %
# [5,   352] loss: 1.245
# Accuracy of the network on the 45000 train images: 64.79 %
# Accuracy of the network on the 5000 valid images: 63.26 %
# Accuracy of the network on the 10000 test images: 65.03 %
# [6,   352] loss: 1.142
# Accuracy of the network on the 45000 train images: 67.55 %
# Accuracy of the network on the 5000 valid images: 66.44 %
# Accuracy of the network on the 10000 test images: 68.07 %
# [7,   352] loss: 1.057
# Accuracy of the network on the 45000 train images: 70.86 %
# Accuracy of the network on the 5000 valid images: 69.52 %
# Accuracy of the network on the 10000 test images: 70.60 %
# [8,   352] loss: 0.992
# Accuracy of the network on the 45000 train images: 71.41 %
# Accuracy of the network on the 5000 valid images: 69.88 %
# Accuracy of the network on the 10000 test images: 70.44 %
# [9,   352] loss: 0.932
# Accuracy of the network on the 45000 train images: 74.58 %
# Accuracy of the network on the 5000 valid images: 72.70 %
# Accuracy of the network on the 10000 test images: 73.52 %
# [10,   352] loss: 0.875
# Accuracy of the network on the 45000 train images: 75.18 %
# Accuracy of the network on the 5000 valid images: 73.18 %
# Accuracy of the network on the 10000 test images: 75.06 %
# [11,   352] loss: 0.829
# Accuracy of the network on the 45000 train images: 77.18 %
# Accuracy of the network on the 5000 valid images: 75.16 %
# Accuracy of the network on the 10000 test images: 77.11 %
# [12,   352] loss: 0.791
# Accuracy of the network on the 45000 train images: 78.05 %
# Accuracy of the network on the 5000 valid images: 75.80 %
# Accuracy of the network on the 10000 test images: 76.35 %
# [13,   352] loss: 0.750
# Accuracy of the network on the 45000 train images: 79.31 %
# Accuracy of the network on the 5000 valid images: 76.68 %
# Accuracy of the network on the 10000 test images: 77.78 %
# [14,   352] loss: 0.715
# Accuracy of the network on the 45000 train images: 78.22 %
# Accuracy of the network on the 5000 valid images: 76.24 %
# Accuracy of the network on the 10000 test images: 77.07 %
# [15,   352] loss: 0.689
# Accuracy of the network on the 45000 train images: 80.79 %
# Accuracy of the network on the 5000 valid images: 77.32 %
# Accuracy of the network on the 10000 test images: 79.38 %
# [16,   352] loss: 0.661
# Accuracy of the network on the 45000 train images: 81.99 %
# Accuracy of the network on the 5000 valid images: 79.80 %
# Accuracy of the network on the 10000 test images: 80.02 %
# [17,   352] loss: 0.629
# Accuracy of the network on the 45000 train images: 82.59 %
# Accuracy of the network on the 5000 valid images: 78.84 %
# Accuracy of the network on the 10000 test images: 80.85 %
# [18,   352] loss: 0.600
# Accuracy of the network on the 45000 train images: 83.79 %
# Accuracy of the network on the 5000 valid images: 80.44 %
# Accuracy of the network on the 10000 test images: 81.41 %
# [19,   352] loss: 0.575
# Accuracy of the network on the 45000 train images: 84.80 %
# Accuracy of the network on the 5000 valid images: 81.14 %
# Accuracy of the network on the 10000 test images: 82.04 %
# [20,   352] loss: 0.547
# Accuracy of the network on the 45000 train images: 85.04 %
# Accuracy of the network on the 5000 valid images: 81.44 %
# Accuracy of the network on the 10000 test images: 82.30 %
# [21,   352] loss: 0.523
# Accuracy of the network on the 45000 train images: 86.08 %
# Accuracy of the network on the 5000 valid images: 81.90 %
# Accuracy of the network on the 10000 test images: 82.73 %
# [22,   352] loss: 0.498
# Accuracy of the network on the 45000 train images: 86.33 %
# Accuracy of the network on the 5000 valid images: 82.28 %
# Accuracy of the network on the 10000 test images: 82.71 %
# [23,   352] loss: 0.483
# Accuracy of the network on the 45000 train images: 86.22 %
# Accuracy of the network on the 5000 valid images: 81.90 %
# Accuracy of the network on the 10000 test images: 82.97 %
# [24,   352] loss: 0.467
# Accuracy of the network on the 45000 train images: 87.21 %
# Accuracy of the network on the 5000 valid images: 82.28 %
# Accuracy of the network on the 10000 test images: 83.28 %
# [25,   352] loss: 0.446
# Accuracy of the network on the 45000 train images: 87.63 %
# Accuracy of the network on the 5000 valid images: 82.40 %
# Accuracy of the network on the 10000 test images: 83.53 %
# [26,   352] loss: 0.427
# Accuracy of the network on the 45000 train images: 88.04 %
# Accuracy of the network on the 5000 valid images: 83.20 %
# Accuracy of the network on the 10000 test images: 83.48 %
# [27,   352] loss: 0.419
# Accuracy of the network on the 45000 train images: 88.21 %
# Accuracy of the network on the 5000 valid images: 82.98 %
# Accuracy of the network on the 10000 test images: 83.42 %
# [28,   352] loss: 0.394
# Accuracy of the network on the 45000 train images: 89.61 %
# Accuracy of the network on the 5000 valid images: 84.34 %
# Accuracy of the network on the 10000 test images: 84.60 %
# [29,   352] loss: 0.384
# Accuracy of the network on the 45000 train images: 89.13 %
# Accuracy of the network on the 5000 valid images: 83.44 %
# Accuracy of the network on the 10000 test images: 84.50 %
# [30,   352] loss: 0.367
# Accuracy of the network on the 45000 train images: 89.99 %
# Accuracy of the network on the 5000 valid images: 84.08 %
# Accuracy of the network on the 10000 test images: 84.36 %
# [31,   352] loss: 0.349
# Accuracy of the network on the 45000 train images: 90.72 %
# Accuracy of the network on the 5000 valid images: 84.68 %
# Accuracy of the network on the 10000 test images: 84.79 %
# [32,   352] loss: 0.337
# Accuracy of the network on the 45000 train images: 91.32 %
# Accuracy of the network on the 5000 valid images: 84.90 %
# Accuracy of the network on the 10000 test images: 84.72 %
# [33,   352] loss: 0.332
# Accuracy of the network on the 45000 train images: 91.21 %
# Accuracy of the network on the 5000 valid images: 84.36 %
# Accuracy of the network on the 10000 test images: 85.02 %
# [34,   352] loss: 0.321
# Accuracy of the network on the 45000 train images: 91.49 %
# Accuracy of the network on the 5000 valid images: 85.30 %
# Accuracy of the network on the 10000 test images: 85.64 %
# [35,   352] loss: 0.296
# Accuracy of the network on the 45000 train images: 91.73 %
# Accuracy of the network on the 5000 valid images: 84.70 %
# Accuracy of the network on the 10000 test images: 85.76 %
# [36,   352] loss: 0.291
# Accuracy of the network on the 45000 train images: 92.27 %
# Accuracy of the network on the 5000 valid images: 85.24 %
# Accuracy of the network on the 10000 test images: 85.34 %
# [37,   352] loss: 0.281
# Accuracy of the network on the 45000 train images: 92.32 %
# Accuracy of the network on the 5000 valid images: 84.42 %
# Accuracy of the network on the 10000 test images: 85.73 %
# [38,   352] loss: 0.271
# Accuracy of the network on the 45000 train images: 92.48 %
# Accuracy of the network on the 5000 valid images: 85.04 %
# Accuracy of the network on the 10000 test images: 86.07 %
# [39,   352] loss: 0.265
# Accuracy of the network on the 45000 train images: 93.26 %
# Accuracy of the network on the 5000 valid images: 85.56 %
# Accuracy of the network on the 10000 test images: 86.03 %
# [40,   352] loss: 0.251
# Accuracy of the network on the 45000 train images: 92.77 %
# Accuracy of the network on the 5000 valid images: 85.02 %
# Accuracy of the network on the 10000 test images: 85.99 %
# [41,   352] loss: 0.250
# Accuracy of the network on the 45000 train images: 93.22 %
# Accuracy of the network on the 5000 valid images: 84.94 %
# Accuracy of the network on the 10000 test images: 86.63 %
# [42,   352] loss: 0.234
# Accuracy of the network on the 45000 train images: 93.36 %
# Accuracy of the network on the 5000 valid images: 84.94 %
# Accuracy of the network on the 10000 test images: 85.94 %
# [43,   352] loss: 0.220
# Accuracy of the network on the 45000 train images: 93.84 %
# Accuracy of the network on the 5000 valid images: 85.38 %
# Accuracy of the network on the 10000 test images: 85.99 %
# [44,   352] loss: 0.211
# Accuracy of the network on the 45000 train images: 94.53 %
# Accuracy of the network on the 5000 valid images: 85.76 %
# Accuracy of the network on the 10000 test images: 86.38 %
# [45,   352] loss: 0.213
# Accuracy of the network on the 45000 train images: 94.40 %
# Accuracy of the network on the 5000 valid images: 85.64 %
# Accuracy of the network on the 10000 test images: 86.13 %
# [46,   352] loss: 0.198
# Accuracy of the network on the 45000 train images: 93.81 %
# Accuracy of the network on the 5000 valid images: 85.02 %
# Accuracy of the network on the 10000 test images: 84.87 %
# [47,   352] loss: 0.195
# Accuracy of the network on the 45000 train images: 94.73 %
# Accuracy of the network on the 5000 valid images: 85.32 %
# Accuracy of the network on the 10000 test images: 86.57 %
# [48,   352] loss: 0.200
# Accuracy of the network on the 45000 train images: 95.14 %
# Accuracy of the network on the 5000 valid images: 86.58 %
# Accuracy of the network on the 10000 test images: 86.63 %
# [49,   352] loss: 0.187
# Accuracy of the network on the 45000 train images: 94.70 %
# Accuracy of the network on the 5000 valid images: 85.76 %
# Accuracy of the network on the 10000 test images: 85.97 %
# [50,   352] loss: 0.175
# Accuracy of the network on the 45000 train images: 94.87 %
# Accuracy of the network on the 5000 valid images: 85.62 %
# Accuracy of the network on the 10000 test images: 85.82 %
# [51,   352] loss: 0.180
# Accuracy of the network on the 45000 train images: 95.79 %
# Accuracy of the network on the 5000 valid images: 86.36 %
# Accuracy of the network on the 10000 test images: 87.20 %
# [52,   352] loss: 0.164
# Accuracy of the network on the 45000 train images: 96.11 %
# Accuracy of the network on the 5000 valid images: 86.48 %
# Accuracy of the network on the 10000 test images: 86.76 %
# [53,   352] loss: 0.165
# Accuracy of the network on the 45000 train images: 95.78 %
# Accuracy of the network on the 5000 valid images: 85.64 %
# Accuracy of the network on the 10000 test images: 87.18 %
# [54,   352] loss: 0.159
# Accuracy of the network on the 45000 train images: 95.63 %
# Accuracy of the network on the 5000 valid images: 85.92 %
# Accuracy of the network on the 10000 test images: 85.88 %
# [55,   352] loss: 0.154
# Accuracy of the network on the 45000 train images: 96.09 %
# Accuracy of the network on the 5000 valid images: 86.32 %
# Accuracy of the network on the 10000 test images: 87.45 %
# [56,   352] loss: 0.155
# Accuracy of the network on the 45000 train images: 96.18 %
# Accuracy of the network on the 5000 valid images: 86.60 %
# Accuracy of the network on the 10000 test images: 86.22 %
# [57,   352] loss: 0.142
# Accuracy of the network on the 45000 train images: 96.29 %
# Accuracy of the network on the 5000 valid images: 86.32 %
# Accuracy of the network on the 10000 test images: 86.85 %
# [58,   352] loss: 0.136
# Accuracy of the network on the 45000 train images: 95.90 %
# Accuracy of the network on the 5000 valid images: 85.32 %
# Accuracy of the network on the 10000 test images: 85.92 %
# [59,   352] loss: 0.131
# Accuracy of the network on the 45000 train images: 96.54 %
# Accuracy of the network on the 5000 valid images: 86.46 %
# Accuracy of the network on the 10000 test images: 86.96 %
# [60,   352] loss: 0.139
# Accuracy of the network on the 45000 train images: 96.46 %
# Accuracy of the network on the 5000 valid images: 86.64 %
# Accuracy of the network on the 10000 test images: 86.65 %
# [61,   352] loss: 0.129
# Accuracy of the network on the 45000 train images: 96.45 %
# Accuracy of the network on the 5000 valid images: 86.34 %
# Accuracy of the network on the 10000 test images: 87.03 %
# [62,   352] loss: 0.123
# Accuracy of the network on the 45000 train images: 96.51 %
# Accuracy of the network on the 5000 valid images: 86.22 %
# Accuracy of the network on the 10000 test images: 86.98 %
# [63,   352] loss: 0.128
# Accuracy of the network on the 45000 train images: 96.76 %
# Accuracy of the network on the 5000 valid images: 86.22 %
# Accuracy of the network on the 10000 test images: 87.02 %
# Process Process-253:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/opt/conda/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/opt/conda/lib/python2.7/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
#   File "/opt/conda/lib/python2.7/site-packages/torch/multiprocessing/queue.py", line 21, in recv
#     buf = self.recv_bytes()
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-9-1e08f7e485f5> in <module>()
#      23
#      24         # print statistics
# ---> 25         running_loss += loss.data[0]
#      26         #if i % 300 == 299:    # print every 2000 mini-batches
#      27     print('[%d, %5d] loss: %.3f' %
#
# KeyboardInterrupt:

# %%
correct = 0
total = 0
for data in testloader2:
    images, labels = data
    outputs = net(Variable(images.cuda()))
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels.cuda()).sum()

print('Accuracy of the network on the 10000 test images: %5.2f %%' % (
    100.0 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 86.72 %

# %%
import matplotlib.pyplot as plt
x = [i for i in range(epoch)]
plt.figure(figsize = (8,6))
trainRate, = plt.plot(x, train.numpy()[:epoch])
validRate, = plt.plot(x, valid.numpy()[:epoch])
testRate, = plt.plot(x, test.numpy()[:epoch])
plt.legend([trainRate, validRate, testRate], ['trainRate', 'validRate', 'testRate'])
plt.xlabel('# of epoch')
plt.ylabel('Percent Correct Classification')
plt.title('Percent Correct Classification of CNN-1')
plt.show()

# %%
class Net2(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(3, 46, 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv1.weight)
        self.conv1_bn = nn.BatchNorm2d(46)
        
        self.conv2 = nn.Conv2d(46, 92, 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv2.weight)
        # an affine operation: y = Wx + b
        self.conv2_bn = nn.BatchNorm2d(92)
        
        self.conv3  = nn.Conv2d(92, 184, 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv3.weight)
        self.conv3_bn = nn.BatchNorm2d(184)
        
        self.conv4  = nn.Conv2d(184, 368 , 3, padding = 1)
        #torch.nn.init.xavier_normal(self.conv4.weight)
        self.conv4_bn = nn.BatchNorm2d(368)
        
        self.conv5 = nn.Conv2d(368, 736, 3, padding = 1)
        self.conv5_bn = nn.BatchNorm2d(736)
        
        self.conv6 = nn.Conv2d(736, 1472, 3, padding = 1)
        self.conv6_bn = nn.BatchNorm2d(1472)
        
        self.fc1 = nn.Linear(1472 * 8 * 8, 736)
        torch.nn.init.xavier_normal(self.fc1.weight)
        #self.fc1_bn = nn.BatchNorm1d(1472)
        
        self.fc2 = nn.Linear(736, 120)
        torch.nn.init.xavier_normal(self.fc2.weight)
        #self.fc2_bn = nn.BatchNorm1d(120)
        
        self.fc3 = nn.Linear(120, 10)
        torch.nn.init.xavier_normal(self.fc3.weight)
        #self.fc3_bn = nn.BatchNorm1d(84)
        
#         self.fc4 = nn.Linear(84, 10)
#         torch.nn.init.xavier_normal(self.fc4.weight)

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.relu(self.conv1_bn(self.conv1(x)))   
        x = F.relu(self.conv2_bn(self.conv2(x))) 
        x = F.max_pool2d(F.relu(self.conv3_bn(self.conv3(x))), (2, 2)) 
        # If the size is a square you can only specify a single number
        x = F.relu(self.conv4_bn(self.conv4(x)))
        x = F.relu(self.conv5_bn(self.conv5(x)))
        x = F.max_pool2d(F.relu(self.conv6_bn(self.conv6(x))), 2)
        
        #x = F.max_pool2d(F.relu(self.conv4_bn(self.conv4(x))), 2)
        
        x = x.view(-1, self.num_flat_features(x))
        
#         x = F.relu(self.fc1_bn(self.fc1(x)))
#         x = F.relu(self.fc2_bn(self.fc2(x)))
#         x = F.relu(self.fc3_bn(self.fc3(x)))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc3(x))
        
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features


net = Net()
net = net.cuda()
print(net)
